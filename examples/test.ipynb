# %%
import torch
from torch.utils.data import Dataset, DataLoader

# Import necessary libraries
# Define a custom dataset
class CustomDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]
        label = self.labels[idx]
        return sample, label

# Define a custom DataLoader subclass
class CustomDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=1, shuffle=False, num_workers=0, collate_fn=None):
        super().__init__(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, collate_fn=collate_fn)

    def __iter__(self):
        # Custom logic for iterating over batches
        for batch in super().__iter__():
            # Apply any additional transformations or operations to the batch
            # ...

            yield batch

# Example data and labels
data = torch.randn(8, 3, 10, 10)  # 100 samples, 10 features each
labels = torch.randn(8, 3, 10, 10)

# Create an instance of CustomDataset
dataset = CustomDataset(data, labels)

# Create an instance of CustomDataLoader
dataloader = CustomDataLoader(dataset, batch_size=4, shuffle=True)


# Example of iterating over DataLoader
for batch_idx, (data, labels) in enumerate(dataloader):
    # Here, you would typically feed 'data' and 'labels' to your model
    print(f"Batch {batch_idx}:")
    print(f"Data: {data.size()}, Labels: {labels.size()}")
    print(f"Labels: {labels[0,0,5,5]}")
    # Break after the first batch for demonstration purposes
# Out:
# Batch 0:
# Data: torch.Size([4, 3, 10, 10]), Labels: torch.Size([4, 3, 10, 10])
# Labels: 0.42486098408699036
# Batch 1:
# Data: torch.Size([4, 3, 10, 10]), Labels: torch.Size([4, 3, 10, 10])
# Labels: -1.5845705270767212

# %%
len(dataloader)
# Out:
# 2

# %%
import numpy as np
len(out[0].shape)
# Out:
# 4

# %%
out = next(iter(dataloader))
out[0].shape
# Out:
# torch.Size([4, 3, 10, 10])
