# %%
import pickle
with open('/volume1/scratch/share_dir/ecsim/peppe/T2D12_filter2/T2D-Fields_000000.h5.pkl', "rb") as n:
    field = pickle.load(n)

# %%
i = 2
j = 3
print(f"{field['Bx'][0,i,j] = }")
print(f"{field['By'][0,i,j] = }")
print(f"{field['Bz'][0,i,j] = }")
print(f"{ (field['Jx_1']/field['rho_1'])[0,i,j] = }")
print(f"{ (field['Jy_1']/field['rho_1'])[0,i,j] = }")
print(f"{ (field['Jz_1']/field['rho_1'])[0,i,j] = }")
# Out:
# field['Bx'][0,i,j] = 0.0033946144733256484
# field['By'][0,i,j] = 0.0008451596268952697
# field['Bz'][0,i,j] = 0.009330039509982638
#  (field['Jx_1']/field['rho_1'])[0,i,j] = 0.004308611682106065
#  (field['Jy_1']/field['rho_1'])[0,i,j] = 0.013480843585248379
#  (field['Jz_1']/field['rho_1'])[0,i,j] = 0.0010514533272317818

# %%
field['Bx'][0,:-1,:-1].shape, (field['Jx_1']/field['rho_1'])[0,:-1,:-1].shape
# Out:
# ((512, 512), (512, 512))
